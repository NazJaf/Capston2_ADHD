# %%
import pandas as pd
df = pd.read_excel(r'C:\Users\Zaur\OneDrive\Desktop\ADHD.xlsx')

df.head()
# Out:
#    age     sex specify      home_language  \
# 0   22  female     NaN           xitsonga
# 1   21    male     NaN            english
# 2   19  female     NaN            isizulu
# 3   20    male     NaN  afrikaans/english
# 4   20  female     NaN           isixhosa
#
#   have_you_ever_experienced_any_mental_health_difficulties_or_symptoms_before_starting_university_e_g_in_primary_or_high_school  \
# 0                                                 no
# 1                                                 no
# 2                                                yes
# 3                                                yes
# 4                                                 no
#
#   if_yes_please_list_these_difficulties_and_or_symptoms  \
# 0                                                 na
# 1                                               none
# 2        mental breakdowns.  anxiety.  panic attacks
# 3            depression and anxiety, as well as adhd
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Columns: 110 entries, age to aas_change
# dtypes: float64(11), int64(83), object(16)
# memory usage: 435.0+ KB
#               age  bdi1_item_1  bdi1_item_2  bdi1_item_3  bdi1_item_4  \
# count  506.000000   506.000000   506.000000   506.000000   506.000000
# mean    18.428854     0.517787     0.478261     0.452569     0.849802
# std      0.720202     0.803877     0.752897     0.775059     0.865837
# min     18.000000     0.000000     0.000000     0.000000     0.000000
# 25%     18.000000     0.000000     0.000000     0.000000     0.000000
# 50%     18.000000     0.000000     0.000000     0.000000     1.000000
# 75%     19.000000     1.000000     1.000000     1.000000     1.000000
# max     22.000000     3.000000     3.000000     3.000000     3.000000
#
#        bdi1_item_5  bdi1_item_6  bdi1_item_7  bdi1_item_8  bdi1_item_9  ...  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Correlation matrix
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
import matplotlib.pyplot as plt


sns.histplot(df['age'], bins=20, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
sns.countplot(x='sex', data=df)
plt.title('Sex Distribution')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# The Beck Anxiety Inventory (BAI) is a self-report questionnaire designed to assess the severity of anxiety symptoms in individuals. It consists of 21 items, each representing a symptom of anxiety. Respondents rate how much they have been bothered by each symptom over the past week on a scale from 0 to 3.

# %%
#The Beck Anxiety Inventory (BAI)
sns.histplot(df['bai1_total'], bins=20, kde=True)
plt.title('BAI Total Scores Distribution')
plt.xlabel('BAI Total Score')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# The Adult ADHD Self-Report Scale (ASRS) is a self-report questionnaire used to assess symptoms of Attention Deficit Hyperactivity Disorder (ADHD) in adults. The ASRS helps identify individuals who may have ADHD or exhibit ADHD-like symptoms.

# %%
sns.boxplot(x=df['asrs1_total.y'])
plt.title('ASRS Total Scores Box Plot')
plt.xlabel('ASRS Total Score')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

top_languages = df['home_language'].value_counts().head(5).index
filtered_df = df[df['home_language'].isin(top_languages)]


plt.figure(figsize=(10, 6))
sns.countplot(data=filtered_df, x='home_language', order=top_languages)
plt.title('Top 5 Home Languages Distribution')
plt.xlabel('Home Language')
plt.ylabel('Count')
plt.show()

# %%
# Count the occurrences of "Yes" and "No"
response_counts = df['have_you_ever_experienced_any_mental_health_difficulties_or_symptoms_before_starting_university_e_g_in_primary_or_high_school'].value_counts()
print(response_counts)
# Out:
# yes    327
# no     179
# Name: have_you_ever_experienced_any_mental_health_difficulties_or_symptoms_before_starting_university_e_g_in_primary_or_high_school, dtype: int64

# %%
# Compare BAI total scores
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='have_you_ever_experienced_any_mental_health_difficulties_or_symptoms_before_starting_university_e_g_in_primary_or_high_school', y='bai1_total')
plt.title('BAI Total Scores by Experience of Difficulties Before University')
plt.xlabel('Experienced Difficulties')
plt.ylabel('BAI Total Score')
plt.show()

# Compare ASRS total scores
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='have_you_ever_experienced_any_mental_health_difficulties_or_symptoms_before_starting_university_e_g_in_primary_or_high_school', y='asrs1_total.y')
plt.title('ASRS Total Scores by Experience of Difficulties Before University')
plt.xlabel('Experienced Difficulties')
plt.ylabel('ASRS Total Score')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df['if_you_have_been_diagnosed_with_a_mental_illness_at_what_age_was_this'] = pd.to_numeric(df['if_you_have_been_diagnosed_with_a_mental_illness_at_what_age_was_this'], errors='coerce')

df_clean = df.dropna(subset=['if_you_have_been_diagnosed_with_a_mental_illness_at_what_age_was_this'])

plt.figure(figsize=(10, 6))
sns.histplot(df_clean['if_you_have_been_diagnosed_with_a_mental_illness_at_what_age_was_this'], bins=20, kde=True)
plt.title('Distribution of Age at Diagnosis of Mental Illness')
plt.xlabel('Age at Diagnosis')
plt.ylabel('Frequency')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df_clean = df.dropna(subset=['if_yes_please_list_these_difficulties_and_or_symptoms'])

# Count the occurrences of each symptom description
symptom_counts = df_clean['if_yes_please_list_these_difficulties_and_or_symptoms'].value_counts()

# Get the top 10 most common symptoms
top_10_symptoms = symptom_counts.head(10)


top_10_df = top_10_symptoms.reset_index()
top_10_df.columns = ['Symptom', 'Count']


plt.figure(figsize=(12, 8))
sns.barplot(x='Count', y='Symptom', data=top_10_df)
plt.title('Top 10 Most Common Symptoms')
plt.xlabel('Count')
plt.ylabel('Symptom')
plt.show()
